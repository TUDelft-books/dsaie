# %% [markdown]
# # Review and Quiz

# %%
from jupyterquiz import display_quiz

# %% [markdown]
# ## Lecture 1: Recurrent Neural Networks

# %%
display_quiz("review_rnn.json")

# %% [markdown]
# ## Lecture 2: Long Short-Term Memory and Other Gated RNNs

# %%
display_quiz("review_lstm.json")
