# %% [markdown]
# # Review and Quiz

# %%
from jupyterquiz import display_quiz

# %% [markdown]
# ## Lecture 2: Dropout Regularization and Probabilistic Deep Learning

# %%
display_quiz("review_probML.json")
