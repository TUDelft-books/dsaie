# %% [markdown]
# # Review and Quiz

# %%
from jupyterquiz import display_quiz

# %% [markdown]
# ## Introduction

# %%
display_quiz("review_intro.json")

# %% [markdown]
# ## Convolutions and Pooling

# %%
display_quiz("review_convpool.json")

# %% [markdown]
# ## CNN for Image Classification

# %%
display_quiz("review_cnn_ic.json")

# %% [markdown]
# ## Invariance, Equivariance and Data Augmentation

# %%
display_quiz("review_inv_equi_da.json")

# %% [markdown]
# ## Residual Networks, Batch Normalization and Transfer Learning

# %%
display_quiz("review_resid_tl.json")

# %% [markdown]
# ## CNNs beyond image classification

# %%
display_quiz("review_beyond_ic.json", question_alignment="left")
